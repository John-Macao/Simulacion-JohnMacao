# %%
import random


def lanzar():
    d1= random.randint(1, 6)

    d2= random.randint(1, 6)

    r= d1+d2

    return r

# %%
from collections import Counter

def repeticiones (n):

    a=[]

    for i in range(n):
        a.append(lanzar())


    ac=Counter(a)

    return ac

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
lista= repeticiones(100)

numeros = list(lista.keys())
veces = list(lista.values())
ax.bar(numeros,veces)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
lista= repeticiones(1000)

numeros = list(lista.keys())
veces = list(lista.values())
ax.bar(numeros,veces)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
lista= repeticiones(10000)

numeros = list(lista.keys())
veces = list(lista.values())
ax.bar(numeros,veces)
plt.show()
